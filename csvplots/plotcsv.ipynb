# %%
import json
from pathlib import Path
from typing import List
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import torch
import torchmetrics
from datetime import datetime
import math

# %%
from plots import ensemble_from_test_csv, ensemble_from_submission_csv

# %%
ensemble_from_test_csv("../data/dev.csv", "label", "./tests", "predict", error_gap=1.5)

# %%
ensemble_from_submission_csv(pred_dir="./submissions/")
